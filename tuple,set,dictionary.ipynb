# %% [markdown]
# TUPLE
# Tuple items are ordered, unchangeable, and allow duplicate values.

# %%
thistuple = ("apple", "banana", "cherry")
print(len(thistuple))
# Out:
# 3

# %% [markdown]
# To create a tuple with only one item, you have to add a comma after the item, otherwise Python will not recognize it as a tuple.

# %%
thistuple = ("apple",)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
#A tuple can contain different data types:
tuple1 = ("abc", 34, True, 40, "male")

# %%
#access tuple items by referring to the index number 
thistuple = ("apple", "banana", "cherry")
print(thistuple[1])
# Out:
# banana

# %%
#Negative indexing means start from the end.
thistuple = ("apple", "banana", "cherry")
print(thistuple[-1])
# Out:
# cherry

# %% [markdown]
# Range of Indexes

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:5])
print(thistuple[:4])
print(thistuple[2:])
print(thistuple[-4:-1]) #negative indexing
# Out:
# ('cherry', 'orange', 'kiwi')
# ('apple', 'banana', 'cherry', 'orange')
# ('cherry', 'orange', 'kiwi', 'melon', 'mango')
# ('orange', 'kiwi', 'melon')

# %%
if "apple" in thistuple:
  print("Yes, 'apple' is in the fruits tuple")
# Out:
# Yes, 'apple' is in the fruits tuple

# %%
#You can convert the tuple into a list, change the list, and convert the list back into a tuple.
x = ("apple", "banana", "cherry")
y = list(x)
y[1] = "kiwi"
x = tuple(y)

print(x)
# Out:
# ('apple', 'kiwi', 'cherry')

# %%
y.append("sapota")
x = tuple(y)

print(x)
# Out:
# ('apple', 'kiwi', 'cherry', 'sapota')

# %%
y.remove("kiwi")
x = tuple(y)

print(x)
# Out:
# ('apple', 'cherry', 'sapota')

# %%
# METHODS
x = (1,5,3,3,7,8,4,9,9)
count() -> x.count(3)
index() -> x.index(9) #Search for the first occurrence of the value 8

# %% [markdown]
# SETS
# A set is a collection which is unordered, unchangeable*, and unindexed.
#
# Once a set is created, you cannot change its items, but you can remove items and add new items.

# %%
# True and 1 is considered the same value, False and 0 is considered the same value:

thisset = {"apple", "banana", "cherry", True, 1, 2}

print(thisset)
# Out:
# {True, 2, 'apple', 'banana', 'cherry'}

# %%
#A set with strings, integers and boolean values:

set1 = {"abc", 34, True, 40, "male"}

# %%
#Access Items
#You cannot access items in a set by referring to an index or a key.
#But you can loop through the set items using a for loop, or ask if a specified value is present in a set, by using the in keyword.

# %%
thisset = {"apple", "banana", "cherry"}

for x in thisset:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
thisset = {"apple", "banana", "cherry"}

print("banana" in thisset)
# Out:
# True

# %%
thisset.add("sapota") #add items
print(thisset)
# Out:
# {'apple', 'sapota', 'banana', 'cherry'}

# %%
set2 = {"mango","opranges"}
thisset.update(set2) #add sets
print(thisset)
# Out:
# {'opranges', 'sapota', 'mango', 'apple', 'banana', 'cherry'}

# %%
lst=["eggs",1,55]
thisset.update(lst)
print(thisset)
# Out:
# {1, 'sapota', 'banana', 'apple', 'cherry', 'opranges', 55, 'mango', 'eggs'}

# %%
#If the item to remove does not exist, remove() will raise an error.
#If the item to remove does not exist, discard() will NOT raise an error.
thisset.remove("eggs")
print(thisset)
# Out:
# {1, 'sapota', 'banana', 'apple', 'cherry', 'opranges', 55, 'mango'}

# %%
#Sets are unordered, so when using the pop() method, you do not know which item that gets removed.
x = thisset.pop()

print(x)

print(thisset)
# Out:
# 1
# {'sapota', 'banana', 'apple', 'cherry', 'opranges', 55, 'mango'}

# %%
#The clear() method empties the set
#The del keyword will delete the set completely

# %% [markdown]
# DICTONARIES
# Dictionaries are used to store data values in key:value pairs.
#
# A dictionary is a collection which is ordered*, changeable and do not allow duplicates.

# %%
d1 = {"name": "kiran",
      "age": 23,
    "loc": "USA"}
print(d1["age"]) #can be referred to by using the key name.
# Out:
# 23

# %%
d1 = {"name": "kiran",
      "age": 23,
    "loc": "USA",
     "loc": "INDIA"} #Dictionaries cannot have two items with the same key
print(d1["loc"])
# Out:
# INDIA

# %%
print(len(d1))
# Out:
# 3

# %%
x = d1.get("name") #can access item by referring to it's key name, by using get() method.
print(x)
# Out:
# kiran

# %%
#get keys
x = d1.keys()
print(x)
# Out:
# dict_keys(['name', 'age', 'loc'])

# %%
x = d1.values()
print(x)
# Out:
# dict_values(['kiran', 23, 'INDIA', 'yes'])

# %%
x = d1.items()
print(x)
# Out:
# dict_items([('name', 'kiran'), ('age', 23), ('loc', 'INDIA'), ('DL', 'yes')])

# %%
#add new item
d1["DL"] = "yes"
print(d1)
# Out:
# {'name': 'kiran', 'age': 23, 'loc': 'INDIA', 'DL': 'yes'}

# %%
#update dictionary
d1.update({'loc':'dubai'})
print(d1)
# Out:
# {'name': 'kiran', 'age': 23, 'loc': 'dubai', 'DL': 'yes'}

# %%
#pop
#popitem() method -> removes the last inserted item( but in 3.7 version, randomly removes item instead)
d1.pop('DL')
print(d1)
# Out:
# {'name': 'kiran', 'age': 23, 'loc': 'dubai'}

# %% [markdown]
# NESTED DICTONARIES
# A dictionary can contain dictionaries, this is called nested dictionaries.

# %%
d2 = {"class1": {"name": "kiran", "num": 6},
      "class2": {"name": "rushi", "num": 8}}
print(d2["class1"])
# Out:
# {'name': 'kiran', 'num': 6}

# %%
d2["class2"]["num"]
# Out:
# 8

# %%
#Shallowcopy
import copy
x = [1,2,3,4]
shallow = copy.copy(x)
shallow[0] = 12

print("x",x)
print("shallow",shallow)
# Out:
# x [1, 2, 3, 4]
# shallow [12, 2, 3, 4]

# %%
shallow = copy.deepcopy(x)
shallow[0] = 12

print("x",x)
print("shallow",shallow)
# Out:
# x [1, 2, 3, 4]
# shallow [12, 2, 3, 4]
